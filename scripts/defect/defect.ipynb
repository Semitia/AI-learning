# %%
import torchvision,torch,time
from torchvision import datasets, transforms
from torch import nn
from torch.utils.data import DataLoader, Dataset
from torch.utils.tensorboard import SummaryWriter
from torch.nn import Conv2d, MaxPool2d, Flatten, Linear, Sequential
from vit_pytorch import ViT
import numpy as np

# 设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("using {} device.".format(device))
import os
current_directory = os.getcwd()
print("Current working directory:", current_directory)
# Out:
# using cuda device.
# Current working directory: d:\CODE\Pycharm\Codes\AI\scripts

# %%
data_dir = '../dataset/Summer_camp/dataset1/'
train_data = datasets.ImageFolder(root=data_dir + 'train', transform=transforms.ToTensor())
test_data = datasets.ImageFolder(root=data_dir + 'val', transform=transforms.ToTensor())

# 计算均值和标准差
mean = np.zeros(3)
std = np.zeros(3)
num_images = 0
for img, _ in train_data:
    mean += img.mean(dim=[1, 2]).numpy()
    std += img.std(dim=[1, 2]).numpy()
    num_images += 1
mean /= num_images
std /= num_images
print(f'Mean: {mean}')
print(f'Std: {std}')
transform = transforms.Compose([
    # transforms.RandomResizedCrop(64),       # 随机裁剪并调整大小
    transforms.RandomHorizontalFlip(),        # 随机水平翻转
    transforms.ToTensor(),                    # 转换为张量
    transforms.Normalize(mean=mean, std=std)  # 归一化
])
train_data = datasets.ImageFolder(root=data_dir + 'train', transform=transform)
test_data = datasets.ImageFolder(root=data_dir + 'val', transform=transform)
train_dataloader = DataLoader(train_data, batch_size=64)
test_dataloader = DataLoader(test_data, batch_size=64)

# 长度
train_data_size = len(train_data)
test_data_size = len(test_data)
print("训练数据集的长度为：{}".format(train_data_size))
print("测试数据集的长度为：{}".format(test_data_size))
# 打印类别到索引的映射
print("Class to index mapping:", train_data.class_to_idx)
# Out:
# Mean: [0.53470237 0.53470237 0.53470237]
# Std: [0.09273925 0.09273925 0.09273925]
# 训练数据集的长度为：5055
# 测试数据集的长度为：1446
# Class to index mapping: {'cr': 0, 'gg': 1, 'in': 2, 'pa': 3, 'ps': 4, 'rp': 5, 'rs': 6, 'sc': 7, 'sp': 8}

# %%
    # img show test
    idx = 0
    img, label = train_data[idx]
    print(img.shape)
    img = transforms.ToPILImage()(img)
    img.show()
    print("Label:", label)
# Out:
# torch.Size([3, 64, 64])
# Label: 0

# %%
# 创建网络模型    
class Tudui(nn.Module):
    def __init__(self):
        super(Tudui, self).__init__()
        self.model1 = Sequential(
            Conv2d(3, 32, 5, padding=2),
            MaxPool2d(2),
            Conv2d(32, 32, 5, padding=2),
            MaxPool2d(2),
            Conv2d(32, 64, 5, padding=2),
            MaxPool2d(2),
            Flatten(),
            Linear(4096, 64),
            Linear(64, 9)
        )

    def forward(self, x):
        x = self.model1(x)
        return x
    

# tudui = ViT(
#     image_size=64,
#     patch_size=8,
#     num_classes=9,
#     dim=256,
#     depth=6,
#     heads=16,
#     mlp_dim=2048,
#     dropout=0.1,
#     emb_dropout=0.1,
# ).to(device)
tudui = Tudui().to(device)
loss_fn = nn.CrossEntropyLoss() # 交叉熵损失函数
loss_fn = loss_fn.to(device)
learning_rate = 1e-3
optimizer = torch.optim.SGD(tudui.parameters(), lr=learning_rate)
input = torch.randn(64, 3, 64, 64).to(device)
output = tudui(input)
print(output.shape)

print()
# Out:
# torch.Size([64, 9])

# %%
total_train_step = 0    # 训练次数
total_test_step = 0     # 测试次数
epoch = 200              # 训练轮数
writer = SummaryWriter("../logs/defect_raw")
last_time = time.time()
for i in range(epoch):
    print("-------第 {} 轮训练开始-------".format(i+1))
    # 训练
    tudui.train() # 对某些特定的层需要此句
    for data in train_dataloader:
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = tudui(inputs)
        loss = loss_fn(outputs, labels)

        # 优化器优化模型
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_train_step = total_train_step + 1
        # if total_train_step % 100 == 0:
        #     print("训练次数：{}, Loss: {}".format(total_train_step, loss.item()))
        #     writer.add_scalar("train_loss", loss.item(), total_train_step)

    # 测试
    tudui.eval() # 对某些特定的层需要此句
    total_test_loss = 0
    total_accuracy = 0
    with torch.no_grad():
        for data in test_dataloader:
            inputs, labels = data
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = tudui(inputs)
            loss = loss_fn(outputs, labels)
            total_test_loss = total_test_loss + loss.item()
            accuracy = (outputs.argmax(1) == labels).sum() # argmax取最大值，argmax(0)竖着看，argmax(1)横着看
            total_accuracy = total_accuracy + accuracy

    print("整体测试集上的Loss: {}".format(total_test_loss))
    print("整体测试集上的正确率: {}".format(total_accuracy/test_data_size))
    writer.add_scalar("test_loss", total_test_loss, total_test_step)
    writer.add_scalar("test_accuracy", total_accuracy/test_data_size, total_test_step)
    total_test_step = total_test_step + 1

    # torch.save(tudui, "../models/tudui_{}.pth".format(i))
    torch.save(tudui.state_dict(), "../models/defect_raw/tudui_{}.pth".format(i))
    delta_time = time.time() - last_time
    last_time = time.time()
    print("模型已保存，耗时：{}".format(delta_time))

writer.close()
# Out:
# -------第 1 轮训练开始-------
# 整体测试集上的Loss: 45.856815338134766
# 整体测试集上的正确率: 0.24550484120845795
# 模型已保存，耗时：2.937410354614258
# -------第 2 轮训练开始-------
# 整体测试集上的Loss: 43.97051638364792
# 整体测试集上的正确率: 0.2856155037879944
# 模型已保存，耗时：2.6496920585632324
# -------第 3 轮训练开始-------
# 整体测试集上的Loss: 43.22853642702103
# 整体测试集上的正确率: 0.29529738426208496
# 模型已保存，耗时：2.66732120513916
# -------第 4 轮训练开始-------
# 整体测试集上的Loss: 43.19661861658096
# 整体测试集上的正确率: 0.2987551987171173
# 模型已保存，耗时：2.636902093887329
# -------第 5 轮训练开始-------
# 整体测试集上的Loss: 43.177236676216125
# 整体测试集上的正确率: 0.29529738426208496
# 模型已保存，耗时：2.6262171268463135
# -------第 6 轮训练开始-------
# 整体测试集上的Loss: 43.21577042341232
# 整体测试集上的正确率: 0.29114800691604614
# 模型已保存，耗时：2.6327688694000244
# -------第 7 轮训练开始-------
# 整体测试集上的Loss: 43.02600824832916
# 整体测试集上的正确率: 0.2904564440250397
# 模型已保存，耗时：2.6032872200012207
# -------第 8 轮训练开始-------
# 整体测试集上的Loss: 42.83336544036865
# 整体测试集上的正确率: 0.2946058213710785
# 模型已保存，耗时：2.623296022415161
# -------第 9 轮训练开始-------
# 整体测试集上的Loss: 42.65147864818573
# 整体测试集上的正确率: 0.2987551987171173
# 模型已保存，耗时：2.6238205432891846
# -------第 10 轮训练开始-------
# 整体测试集上的Loss: 42.45538967847824
# 整体测试集上的正确率: 0.305670827627182
# 模型已保存，耗时：2.623771905899048
# -------第 11 轮训练开始-------
# 整体测试集上的Loss: 42.35373955965042
# 整体测试集上的正确率: 0.3008298873901367
# 模型已保存，耗时：2.6217055320739746
# -------第 12 轮训练开始-------
# 整体测试集上的Loss: 42.14711833000183
# 整体测试集上的正确率: 0.30497926473617554
# 模型已保存，耗时：2.6085002422332764
# -------第 13 轮训练开始-------
# 整体测试集上的Loss: 41.991718888282776
# 整体测试集上的正确率: 0.3105117678642273
# 模型已保存，耗时：2.6181836128234863
# -------第 14 轮训练开始-------
# 整体测试集上的Loss: 41.86629903316498
# 整体测试集上的正确率: 0.31189489364624023
# 模型已保存，耗时：2.624593734741211
# -------第 15 轮训练开始-------
# 整体测试集上的Loss: 41.56322884559631
# 整体测试集上的正确率: 0.3125864565372467
# 模型已保存，耗时：2.6216886043548584
# -------第 16 轮训练开始-------
# 整体测试集上的Loss: 41.43149799108505
# 整体测试集上的正确率: 0.3167358338832855
# 模型已保存，耗时：2.5964303016662598
# -------第 17 轮训练开始-------
# 整体测试集上的Loss: 41.06693381071091
# 整体测试集上的正确率: 0.3195020854473114
# 模型已保存，耗时：2.6422250270843506
# -------第 18 轮训练开始-------
# 整体测试集上的Loss: 40.788537323474884
# 整体测试集上的正确率: 0.32019364833831787
# 模型已保存，耗时：2.619391441345215
# -------第 19 轮训练开始-------
# 整体测试集上的Loss: 40.501840710639954
# 整体测试集上的正确率: 0.3132780194282532
# 模型已保存，耗时：2.585460901260376
# -------第 20 轮训练开始-------
# 整体测试集上的Loss: 40.17374086380005
# 整体测试集上的正确率: 0.3215767741203308
# 模型已保存，耗时：2.5140254497528076
# -------第 21 轮训练开始-------
# 整体测试集上的Loss: 39.80023217201233
# 整体测试集上的正确率: 0.32710927724838257
# 模型已保存，耗时：2.5787785053253174
# -------第 22 轮训练开始-------
# 整体测试集上的Loss: 39.48054367303848
# 整体测试集上的正确率: 0.317427396774292
# 模型已保存，耗时：2.6427128314971924
# -------第 23 轮训练开始-------
# 整体测试集上的Loss: 39.10761171579361
# 整体测试集上的正确率: 0.3215767741203308
# 模型已保存，耗时：2.620023727416992
# -------第 24 轮训练开始-------
# 整体测试集上的Loss: 38.725881695747375
# 整体测试集上的正确率: 0.32503458857536316
# 模型已保存，耗时：2.583991765975952
# -------第 25 轮训练开始-------
# 整体测试集上的Loss: 38.347053945064545
# 整体测试集上的正确率: 0.32987552881240845
# 模型已保存，耗时：2.5890722274780273
# -------第 26 轮训练开始-------
# 整体测试集上的Loss: 37.97875016927719
# 整体测试集上的正确率: 0.33402490615844727
# 模型已保存，耗时：2.5943515300750732
# -------第 27 轮训练开始-------
# 整体测试集上的Loss: 37.59869742393494
# 整体测试集上的正确率: 0.3450899124145508
# 模型已保存，耗时：2.562187433242798
# -------第 28 轮训练开始-------
# 整体测试集上的Loss: 37.27806669473648
# 整体测试集上的正确率: 0.339557409286499
# 模型已保存，耗时：2.5955464839935303
# -------第 29 轮训练开始-------
# 整体测试集上的Loss: 36.98284476995468
# 整体测试集上的正确率: 0.35269710421562195
# 模型已保存，耗时：2.6360979080200195
# -------第 30 轮训练开始-------
# 整体测试集上的Loss: 36.648234367370605
# 整体测试集上的正确率: 0.3492392897605896
# 模型已保存，耗时：2.5978591442108154
# -------第 31 轮训练开始-------
# 整体测试集上的Loss: 36.338872373104095
# 整体测试集上的正确率: 0.3589211702346802
# 模型已保存，耗时：2.636232376098633
# -------第 32 轮训练开始-------
# 整体测试集上的Loss: 36.05939620733261
# 整体测试集上的正确率: 0.35684648156166077
# 模型已保存，耗时：2.58994460105896
# -------第 33 轮训练开始-------
# 整体测试集上的Loss: 35.874586284160614
# 整体测试集上的正确率: 0.36168742179870605
# 模型已保存，耗时：2.5874335765838623
# -------第 34 轮训练开始-------
# 整体测试集上的Loss: 35.64859181642532
# 整体测试集上的正确率: 0.3609958589076996
# 模型已保存，耗时：2.608245372772217
# -------第 35 轮训练开始-------
# 整体测试集上的Loss: 35.411521196365356
# 整体测试集上的正确率: 0.36860305070877075
# 模型已保存，耗时：2.6248440742492676
# -------第 36 轮训练开始-------
# 整体测试集上的Loss: 35.14055424928665
# 整体测试集上的正确率: 0.37275242805480957
# 模型已保存，耗时：2.611520528793335
# -------第 37 轮训练开始-------
# 整体测试集上的Loss: 34.9526144862175
# 整体测试集上的正确率: 0.37551867961883545
# 模型已保存，耗时：2.5702147483825684
# -------第 38 轮训练开始-------
# 整体测试集上的Loss: 34.726501286029816
# 整体测试集上的正确率: 0.37344399094581604
# 模型已保存，耗时：2.597574472427368
# -------第 39 轮训练开始-------
# 整体测试集上的Loss: 34.593562722206116
# 整体测试集上的正确率: 0.37344399094581604
# 模型已保存，耗时：2.6106503009796143
# -------第 40 轮训练开始-------
# 整体测试集上的Loss: 34.388828575611115
# 整体测试集上的正确率: 0.37828493118286133
# 模型已保存，耗时：2.600008249282837
# -------第 41 轮训练开始-------
# 整体测试集上的Loss: 34.29304128885269
# 整体测试集上的正确率: 0.38035961985588074
# 模型已保存，耗时：2.573354959487915
# -------第 42 轮训练开始-------
# 整体测试集上的Loss: 34.099861204624176
# 整体测试集上的正确率: 0.39142462611198425
# 模型已保存，耗时：2.594109058380127
# -------第 43 轮训练开始-------
# 整体测试集上的Loss: 34.06201171875
# 整体测试集上的正确率: 0.39419087767601013
# 模型已保存，耗时：2.570103645324707
# -------第 44 轮训练开始-------
# 整体测试集上的Loss: 33.800084352493286
# 整体测试集上的正确率: 0.3990318179130554
# 模型已保存，耗时：2.6353023052215576
# -------第 45 轮训练开始-------
# 整体测试集上的Loss: 33.65932208299637
# 整体测试集上的正确率: 0.40940526127815247
# 模型已保存，耗时：2.581960678100586
# -------第 46 轮训练开始-------
# 整体测试集上的Loss: 33.57189428806305
# 整体测试集上的正确率: 0.41217151284217834
# 模型已保存，耗时：2.5873215198516846
# -------第 47 轮训练开始-------
# 整体测试集上的Loss: 33.37868469953537
# 整体测试集上的正确率: 0.42392808198928833
# 模型已保存，耗时：2.626512050628662
# -------第 48 轮训练开始-------
# 整体测试集上的Loss: 33.31895035505295
# 整体测试集上的正确率: 0.4273858964443207
# 模型已保存，耗时：2.599430799484253
# -------第 49 轮训练开始-------
# 整体测试集上的Loss: 33.183351278305054
# 整体测试集上的正确率: 0.4432918429374695
# 模型已保存，耗时：2.633826494216919
# -------第 50 轮训练开始-------
# 整体测试集上的Loss: 33.085236966609955
# 整体测试集上的正确率: 0.4522821605205536
# 模型已保存，耗时：2.6500842571258545
