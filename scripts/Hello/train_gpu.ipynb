# %%
import torchvision,torch,time
from torch import nn
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torch.nn import Conv2d, MaxPool2d, Flatten, Linear, Sequential

# 设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("using {} device.".format(device))
import os
current_directory = os.getcwd()
print("Current working directory:", current_directory)
# Out:
# using cuda device.
# Current working directory: d:\CODE\Pycharm\Codes\AI\scripts

# %%
dataset_transform = torchvision.transforms.ToTensor()
train_data = torchvision.datasets.FashionMNIST(root="../dataset", train=True, transform=dataset_transform, download=False)
test_data = torchvision.datasets.FashionMNIST(root="../dataset", train=False, transform=dataset_transform, download=False)
train_dataloader = DataLoader(train_data, batch_size=64)
test_dataloader = DataLoader(test_data, batch_size=64)
# length 长度
train_data_size = len(train_data)
test_data_size = len(test_data)
print("训练数据集的长度为：{}".format(train_data_size))
print("测试数据集的长度为：{}".format(test_data_size))
# Out:
# 训练数据集的长度为：60000
# 测试数据集的长度为：10000

# %%
# 创建网络模型    
class Tudui(nn.Module):
    def __init__(self):
        super(Tudui, self).__init__()
        self.model1 = Sequential(
            Conv2d(1, 32, 5, padding=4),
            MaxPool2d(2),
            Conv2d(32, 32, 5, padding=2),
            MaxPool2d(2),
            Conv2d(32, 64, 5, padding=2),
            MaxPool2d(2),
            Flatten(),
            Linear(1024, 64),
            Linear(64, 10)
        )

    def forward(self, x):
        x = self.model1(x)
        return x
    
    
tudui = Tudui()
tudui = tudui.to(device)
loss_fn = nn.CrossEntropyLoss() # 交叉熵损失函数
loss_fn = loss_fn.to(device)
learning_rate = 1e-2
optimizer = torch.optim.SGD(tudui.parameters(), lr=learning_rate)

# %%
total_train_step = 0    # 训练次数
total_test_step = 0     # 测试次数
epoch = 10              # 训练轮数
writer = SummaryWriter("../logs/hello_train")
last_time = time.time()
for i in range(epoch):
    print("-------第 {} 轮训练开始-------".format(i+1))
    # 训练
    tudui.train() # 对某些特定的层需要此句
    for data in train_dataloader:
        inputs, labels = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        outputs = tudui(inputs)
        loss = loss_fn(outputs, labels)

        # 优化器优化模型
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_train_step = total_train_step + 1
        if total_train_step % 100 == 0:
            print("训练次数：{}, Loss: {}".format(total_train_step, loss.item()))
            writer.add_scalar("train_loss", loss.item(), total_train_step)

    # 测试
    tudui.eval() # 对某些特定的层需要此句
    total_test_loss = 0
    total_accuracy = 0
    with torch.no_grad():
        for data in test_dataloader:
            inputs, labels = data
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = tudui(inputs)
            loss = loss_fn(outputs, labels)
            total_test_loss = total_test_loss + loss.item()
            accuracy = (outputs.argmax(1) == labels).sum() # argmax(0)竖着看，argmax(1)横着看
            total_accuracy = total_accuracy + accuracy

    print("整体测试集上的Loss: {}".format(total_test_loss))
    print("整体测试集上的正确率: {}".format(total_accuracy/test_data_size))
    writer.add_scalar("test_loss", total_test_loss, total_test_step)
    writer.add_scalar("test_accuracy", total_accuracy/test_data_size, total_test_step)
    total_test_step = total_test_step + 1

    # torch.save(tudui, "../models/tudui_{}.pth".format(i))
    torch.save(tudui.state_dict(), "../models/hello/tudui_{}.pth".format(i))
    delta_time = time.time() - last_time
    last_time = time.time()
    print("模型已保存，耗时：{}".format(delta_time))

writer.close()
# Out:
# -------第 1 轮训练开始-------
# 训练次数：100, Loss: 2.1981961727142334
# 训练次数：200, Loss: 1.2870551347732544
# 训练次数：300, Loss: 0.7702668309211731
# 训练次数：400, Loss: 1.1034637689590454
# 训练次数：500, Loss: 0.5685068368911743
# 训练次数：600, Loss: 0.7223761677742004
# 训练次数：700, Loss: 0.8043175935745239
# 训练次数：800, Loss: 0.8256446123123169
# 训练次数：900, Loss: 0.6364452838897705
# 整体测试集上的Loss: 109.98532316088676
# 整体测试集上的正确率: 0.7400999665260315
# 模型已保存，耗时：5.638753175735474
# -------第 2 轮训练开始-------
# 训练次数：1000, Loss: 1.005487322807312
# 训练次数：1100, Loss: 0.470580130815506
# 训练次数：1200, Loss: 0.7523921728134155
# 训练次数：1300, Loss: 0.6288613080978394
# 训练次数：1400, Loss: 0.715059757232666
# 训练次数：1500, Loss: 0.44157931208610535
# 训练次数：1600, Loss: 0.6553359031677246
# 训练次数：1700, Loss: 0.7917965650558472
# 训练次数：1800, Loss: 0.4152218997478485
# 整体测试集上的Loss: 95.1270564198494
# 整体测试集上的正确率: 0.777899980545044
# 模型已保存，耗时：5.564596176147461
# -------第 3 轮训练开始-------
# 训练次数：1900, Loss: 0.5894593000411987
# 训练次数：2000, Loss: 0.8065975904464722
# 训练次数：2100, Loss: 0.5664295554161072
# 训练次数：2200, Loss: 0.6582052111625671
# 训练次数：2300, Loss: 0.5540036559104919
# 训练次数：2400, Loss: 0.6955653429031372
# 训练次数：2500, Loss: 0.5235966444015503
# 训练次数：2600, Loss: 0.5107228755950928
# 训练次数：2700, Loss: 0.5456763505935669
# 训练次数：2800, Loss: 0.4122307002544403
# 整体测试集上的Loss: 85.29723024368286
# 整体测试集上的正确率: 0.8007999658584595
# 模型已保存，耗时：6.758020639419556
# -------第 4 轮训练开始-------
# 训练次数：2900, Loss: 0.6094852685928345
# 训练次数：3000, Loss: 0.8299857378005981
# 训练次数：3100, Loss: 0.6685468554496765
# 训练次数：3200, Loss: 0.41072535514831543
# 训练次数：3300, Loss: 0.3000272512435913
# 训练次数：3400, Loss: 0.4358711540699005
# 训练次数：3500, Loss: 0.4108774662017822
# 训练次数：3600, Loss: 0.5312268137931824
# 训练次数：3700, Loss: 0.4681984782218933
# 整体测试集上的Loss: 79.29593859612942
# 整体测试集上的正确率: 0.8143999576568604
# 模型已保存，耗时：5.716145038604736
# -------第 5 轮训练开始-------
# 训练次数：3800, Loss: 0.3135944902896881
# 训练次数：3900, Loss: 0.5595991611480713
# 训练次数：4000, Loss: 0.19639353454113007
# 训练次数：4100, Loss: 0.5600346326828003
# 训练次数：4200, Loss: 0.4216272234916687
# 训练次数：4300, Loss: 0.2876351773738861
# 训练次数：4400, Loss: 0.3693936765193939
# 训练次数：4500, Loss: 0.27737370133399963
# 训练次数：4600, Loss: 0.4618677794933319
# 整体测试集上的Loss: 74.59259051084518
# 整体测试集上的正确率: 0.8276999592781067
# 模型已保存，耗时：5.603552341461182
# -------第 6 轮训练开始-------
# 训练次数：4700, Loss: 0.5217494964599609
# 训练次数：4800, Loss: 0.39746248722076416
# 训练次数：4900, Loss: 0.4410819411277771
# 训练次数：5000, Loss: 0.5328289270401001
# 训练次数：5100, Loss: 0.6275737881660461
# 训练次数：5200, Loss: 0.289268434047699
# 训练次数：5300, Loss: 0.32751795649528503
# 训练次数：5400, Loss: 0.32313939929008484
# 训练次数：5500, Loss: 0.292083740234375
# 训练次数：5600, Loss: 0.5014034509658813
# 整体测试集上的Loss: 71.5283832848072
# 整体测试集上的正确率: 0.833899974822998
# 模型已保存，耗时：5.662987947463989
# -------第 7 轮训练开始-------
# 训练次数：5700, Loss: 0.2186126857995987
# 训练次数：5800, Loss: 0.2307455837726593
# 训练次数：5900, Loss: 0.4448748826980591
# 训练次数：6000, Loss: 0.37245792150497437
# 训练次数：6100, Loss: 0.5223223567008972
# 训练次数：6200, Loss: 0.26858270168304443
# 训练次数：6300, Loss: 0.42754989862442017
# 训练次数：6400, Loss: 0.3426067531108856
# 训练次数：6500, Loss: 0.36567479372024536
# 整体测试集上的Loss: 69.13471674919128
# 整体测试集上的正确率: 0.8384000062942505
# 模型已保存，耗时：5.734554767608643
# -------第 8 轮训练开始-------
# 训练次数：6600, Loss: 0.36254721879959106
# 训练次数：6700, Loss: 0.4768659472465515
# 训练次数：6800, Loss: 0.35467833280563354
# 训练次数：6900, Loss: 0.4622285068035126
# 训练次数：7000, Loss: 0.3616056740283966
# 训练次数：7100, Loss: 0.2810143530368805
# 训练次数：7200, Loss: 0.5175725817680359
# 训练次数：7300, Loss: 0.35489344596862793
# 训练次数：7400, Loss: 0.24402935802936554
# 训练次数：7500, Loss: 0.36991944909095764
# 整体测试集上的Loss: 66.87832552194595
# 整体测试集上的正确率: 0.8448999524116516
# 模型已保存，耗时：6.0589094161987305
# -------第 9 轮训练开始-------
# 训练次数：7600, Loss: 0.3039688169956207
# 训练次数：7700, Loss: 0.19026325643062592
# 训练次数：7800, Loss: 0.32498109340667725
# 训练次数：7900, Loss: 0.2673753798007965
# 训练次数：8000, Loss: 0.364860862493515
# 训练次数：8100, Loss: 0.41349488496780396
# 训练次数：8200, Loss: 0.2541618049144745
# 训练次数：8300, Loss: 0.3090587854385376
# 训练次数：8400, Loss: 0.2395859658718109
# 整体测试集上的Loss: 65.00962528586388
# 整体测试集上的正确率: 0.8486999869346619
# 模型已保存，耗时：5.810761451721191
# -------第 10 轮训练开始-------
# 训练次数：8500, Loss: 0.25973641872406006
# 训练次数：8600, Loss: 0.35029321908950806
# 训练次数：8700, Loss: 0.39244234561920166
# 训练次数：8800, Loss: 0.2536775469779968
# 训练次数：8900, Loss: 0.3447936475276947
# 训练次数：9000, Loss: 0.610344409942627
# 训练次数：9100, Loss: 0.4215223789215088
# 训练次数：9200, Loss: 0.31434202194213867
# 训练次数：9300, Loss: 0.2928614914417267
# 整体测试集上的Loss: 63.06512151658535
# 整体测试集上的正确率: 0.8552999496459961
# 模型已保存，耗时：5.688140392303467
