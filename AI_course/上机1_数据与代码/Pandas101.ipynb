# %%
import pandas as pd

# %%
csv_path = 'HousingData.csv'

# %%
housing_data_dataframe = pd.read_csv(csv_path)

# %%
housing_data_dataframe
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
housing_data_dataframe['CRIM']
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64

# %%
crim_array = housing_data_dataframe['CRIM'].to_numpy()
crim_array
# Out:
# array([6.32000e-03, 2.73100e-02, 2.72900e-02, 3.23700e-02, 6.90500e-02,
#        2.98500e-02, 8.82900e-02, 1.44550e-01, 2.11240e-01, 1.70040e-01,
#        2.24890e-01, 1.17470e-01, 9.37800e-02, 6.29760e-01, 6.37960e-01,
#        6.27390e-01, 1.05393e+00, 7.84200e-01, 8.02710e-01, 7.25800e-01,
#        1.25179e+00, 8.52040e-01, 1.23247e+00, 9.88430e-01, 7.50260e-01,
#        8.40540e-01, 6.71910e-01, 9.55770e-01, 7.72990e-01, 1.00245e+00,
#        1.13081e+00, 1.35472e+00, 1.38799e+00, 1.15172e+00, 1.61282e+00,
#        6.41700e-02, 9.74400e-02, 8.01400e-02, 1.75050e-01, 2.76300e-02,
#        3.35900e-02, 1.27440e-01, 1.41500e-01, 1.59360e-01, 1.22690e-01,
#        1.71420e-01, 1.88360e-01, 2.29270e-01, 2.53870e-01, 2.19770e-01,
#        8.87300e-02, 4.33700e-02, 5.36000e-02,         nan, 1.36000e-02,
#        1.31100e-02, 2.05500e-02, 1.43200e-02, 1.54450e-01, 1.03280e-01,
#        1.49320e-01, 1.71710e-01, 1.10270e-01, 1.26500e-01, 1.95100e-02,
# ...

# %%
housing_data_dataframe[['CRIM','ZN','DIS']]
# Out:
#         CRIM    ZN     DIS
# 0    0.00632  18.0  4.0900
# 1    0.02731   0.0  4.9671
# 2    0.02729   0.0  4.9671
# 3    0.03237   0.0  6.0622
# 4    0.06905   0.0  6.0622
# ..       ...   ...     ...
# 501  0.06263   0.0  2.4786
# 502  0.04527   0.0  2.2875
# 503  0.06076   0.0  2.1675
# 504  0.10959   0.0  2.3889
# 505  0.04741   0.0  2.5050
#
# [506 rows x 3 columns]

# %%
three_feature_array = housing_data_dataframe[['CRIM','ZN','DIS']].to_numpy()
three_feature_array
# Out:
# array([[6.3200e-03, 1.8000e+01, 4.0900e+00],
#        [2.7310e-02, 0.0000e+00, 4.9671e+00],
#        [2.7290e-02, 0.0000e+00, 4.9671e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 2.1675e+00],
#        [1.0959e-01, 0.0000e+00, 2.3889e+00],
#        [4.7410e-02, 0.0000e+00, 2.5050e+00]])

# %%
three_feature_array.shape
# Out:
# (506, 3)
